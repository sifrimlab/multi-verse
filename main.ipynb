# %%
import json
import os
from train import Trainer
import warnings
# Suppress all warnings
warnings.filterwarnings('ignore')

import torch
torch.cuda.is_available()
# Out:
# /home/thihanh/miniconda3/envs/myenv/lib/python3.12/site-packages/anndata/utils.py:429: FutureWarning: Importing read_csv from `anndata` is deprecated. Import anndata.io.read_csv instead.
#   warnings.warn(msg, FutureWarning)
# /home/thihanh/miniconda3/envs/myenv/lib/python3.12/site-packages/anndata/utils.py:429: FutureWarning: Importing read_excel from `anndata` is deprecated. Import anndata.io.read_excel instead.
#   warnings.warn(msg, FutureWarning)
# /home/thihanh/miniconda3/envs/myenv/lib/python3.12/site-packages/anndata/utils.py:429: FutureWarning: Importing read_hdf from `anndata` is deprecated. Import anndata.io.read_hdf instead.
#   warnings.warn(msg, FutureWarning)
# /home/thihanh/miniconda3/envs/myenv/lib/python3.12/site-packages/anndata/utils.py:429: FutureWarning: Importing read_loom from `anndata` is deprecated. Import anndata.io.read_loom instead.
#   warnings.warn(msg, FutureWarning)
# ...

# %%
my_trainer = Trainer(config_path="./config.json")
my_trainer.model_select()
# Out:
# Loaded configuration successfully.
# Loaded configuration successfully.
# Loaded configuration successfully.
# Initializing PCA Model
# Loaded configuration successfully.
# PCA initialized with pbmc_10k, 20 components.
# Loaded configuration successfully.
# Loaded configuration successfully.
# Initializing MOFA+ Model
# Loaded configuration successfully.
# MOFA+ initialized with pbmc_10k, 20 factors to be trained with.
# Loaded configuration successfully.
# Loaded configuration successfully.
# Initializing MultiVI Model
# Loaded configuration successfully.
# {'pca': <model_v2.PCA_Model at 0x7582e10dbec0>,
#  'mofa+': <model_v2.MOFA_Model at 0x7582e0eabcb0>,
#  'multivi': <model_v2.MultiVI_Model at 0x7582d69650a0>}

# %%
print(my_trainer.models)
print(my_trainer.models["pca"].dataset)
print(my_trainer.models["mofa+"].dataset)
# Out:
# {'pca': <model_v2.PCA_Model object at 0x7582e10dbec0>, 'mofa+': <model_v2.MOFA_Model object at 0x7582e0eabcb0>, 'multivi': <model_v2.MultiVI_Model object at 0x7582d69650a0>}
# AnnData object with n_obs × n_vars = 9505 × 17000
#     obs: 'cell_type', 'modality'
#     var: 'feature_types', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     layers: 'counts'
# MuData object with n_obs × n_vars = 9505 × 17000
#   obs:	'cell_type'
#   var:	'feature_types', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#   2 modalities
#     rna:	9505 x 2000
# ...

# %%
my_trainer.train()
# Out:
# Training PCA Model
# PCA completed with 20 components
# Training MOFA+ Model
#
#         #########################################################
#         ###           __  __  ____  ______                    ###
#         ###          |  \/  |/ __ \|  ____/\    _             ###
#         ###          | \  / | |  | | |__ /  \ _| |_           ###
#         ###          | |\/| | |  | |  __/ /\ \_   _|          ###
#         ###          | |  | | |__| | | / ____ \|_|            ###
#         ###          |_|  |_|\____/|_|/_/    \_\              ###
#         ###                                                   ###
#         #########################################################
#
#
#
# Loaded view='rna' group='group1' with N=9505 samples and D=2000 features...
# Loaded view='atac' group='group1' with N=9505 samples and D=15000 features...
#
#
# Model options:
# - Automatic Relevance Determination prior on the factors: True
# ...

# %%
pca = my_trainer.models["pca"]
mofa = my_trainer.models["mofa+"]
multivi = my_trainer.models["multivi"]

# %%
print(pca.dataset)
print(mofa.dataset)
# Out:
# AnnData object with n_obs × n_vars = 9505 × 17000
#     obs: 'cell_type', 'modality'
#     var: 'feature_types', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'pca'
#     obsm: 'X_pca'
#     varm: 'PCs'
#     layers: 'counts'
# MuData object with n_obs × n_vars = 9505 × 17000
#   obs:	'cell_type'
#   var:	'feature_types', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#   uns:	'mofa'
#   obsm:	'X_mofa'
#   varm:	'LFs'
#   2 modalities
#     rna:	9505 x 2000
# ...

# %%
pca.umap()
# Out:
# Generating UMAP with PCA embeddings for all modalities
# WARNING: saving figure to file outputs/pca_output/umap_pca_pbmc_10k_plot.png
# UMAP plot for pca pbmc_10k saved as _pca_pbmc_10k_plot.png

# %%
mofa.umap()
# Out:
# Generating UMAP with MOFA embeddings
# WARNING: saving figure to file outputs/mofa_output/umap_mofa_pbmc_10k_plot.png
# UMAP plot saved as _mofa_pbmc_10k_plot.png

# %%
multivi.umap()
# Out:
# Generating UMAP plot
# WARNING: saving figure to file outputs/mofa_output/umap./outputs/multivi_outputmultivi_pbmc_10k_umap_plot.png
# Error generating UMAP: [Errno 2] No such file or directory: '/media/gambino/students_workdir/thihanh/IBP/test_code/outputs/mofa_output/umap./outputs/multivi_outputmultivi_pbmc_10k_umap_plot.png'
